# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# 8.3.240

# %%
from ultralytics import YOLO

model = YOLO("best.pt")

# %%
results = model("test.jpg", conf=0.4)
results[0].show()
# Out:
# image 1/1 c:\Users\This PC\OneDrive\Desktop\Yolo\test.jpg: 512x640 1 Happy, 195.1ms
# Speed: 8.8ms preprocess, 195.1ms inference, 17.8ms postprocess per image at shape (1, 3, 512, 640)
